# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
df_cleaned = pd.read_csv("Final Merged Dataset.csv")
df_cleaned
# Out:
#     Unnamed: 0                      Area      Years     Revenue  Subscribers  \
# 0            0  United States and Canada  Q1 - 2018  1976157000     60909000
# 1            1  United States and Canada  Q2 - 2018  2049546000     61870000
# 2            2  United States and Canada  Q3 - 2018  2094850000     63010000
# 3            3  United States and Canada  Q4 - 2018  2160979000     64757000
# 4            4  United States and Canada  Q1 - 2019  2256851000     66633000
# ..         ...                       ...        ...         ...          ...
# 75          75              Asia-Pacific  Q4 - 2021   870705000     32632000
# 76          76              Asia-Pacific  Q1 - 2022   916754000     33719000
# 77          77              Asia-Pacific  Q2 - 2022   907719000     34799000
# 78          78              Asia-Pacific  Q3 - 2022   889037000     36228000
# 79          79              Asia-Pacific  Q4 - 2022   856711000     38023000
#
# ...

# %%
#Generate a scatter plot of revenue vs. stock price

revenue = df_cleaned.groupby("Years")["Revenue"].sum()
stock_price = df_cleaned.groupby("Years")["Close"].mean()

plt.scatter(revenue, stock_price, color='blue')
plt.xlabel("Revenue")
plt.ylabel("Stock Price")
plt.show()

# %%
# Calculate the correlation coefficient and linear regression model for revenue vs.stock price
corr = average_revenue.corr(stock_price).round(2)
print(f"The correlation between Revenue and Stock Price is {corr}")

pe_slope, pe_int, pe_r, pe_p, pe_std_err = st.linregress(revenue, stock_price)
pe_fit = pe_slope * stock_price + pe_int

plt.figure(figsize=(6,4))
plt.scatter(revenue, stock_price, color='blue')
plt.plot(revenue,pe_fit, color = "red")
plt.xlabel('Revenue')
plt.ylabel('Stock Price')
plt.show()
# Out:
# The correlation between Revenue and Stock Price is 0.22
