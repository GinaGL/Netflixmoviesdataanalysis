# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
df_cleaned = pd.read_csv("Final Merged Dataset.csv")
df_cleaned.head()
# Out:
#    Unnamed: 0                      Area      Years     Revenue  Subscribers  \
# 0           0  United States and Canada  Q1 - 2018  1976157000     60909000
# 1           1  United States and Canada  Q2 - 2018  2049546000     61870000
# 2           2  United States and Canada  Q3 - 2018  2094850000     63010000
# 3           3  United States and Canada  Q4 - 2018  2160979000     64757000
# 4           4  United States and Canada  Q1 - 2019  2256851000     66633000
#
#          Open        High         Low       Close   Adj Close     Volume
# 0  291.940002  338.820007  271.220001  312.459991  312.459991  262006000
# 1  385.450012  419.769989  328.000000  337.450012  337.450012  305393800
# 2  375.850006  386.799988  271.209991  301.779999  301.779999  363589800
# 3  259.279999  358.850006  256.579987  339.500000  339.500000  306616400
# 4  359.000000  384.799988  342.269989  370.540009  370.540009  165079400

# %%
#Generate a scatter plot of average revenue vs. stock price

average_revenue = df_cleaned.groupby("Years")["Revenue"].mean()
stock_price = df_cleaned.groupby("Years")["Close"].mean()

plt.scatter(average_revenue, stock_price, color='blue')
plt.xlabel("Revenue")
plt.ylabel("Stock Price")
plt.show()

# %%
# Calculate the correlation coefficient and linear regression model 
# for average revenue vs.stock price
corr = average_revenue.corr(stock_price).round(2)
print(f"The correlation between Revenue and Stock Price is {corr}")

pe_slope, pe_int, pe_r, pe_p, pe_std_err = st.linregress(average_revenue, stock_price)
pe_fit = pe_slope * stock_price + pe_int

plt.figure(figsize=(5,3))
plt.scatter(average_revenue, stock_price, color='steelblue')
plt.plot(average_revenue,pe_fit, color = "red")
plt.xticks(average_revenue, rotation=50)
plt.xlabel('Revenue')
plt.ylabel('Stock Price')
plt.show()
# Out:
# The correlation between Revenue and Stock Price is 0.22
