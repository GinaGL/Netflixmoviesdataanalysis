# %%
# Dependencies and Setup
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# File to Load (Remember to Change These)
movie_netflix = "Merged_Netflix_movie&rating.csv"
stock_netflix = "Final Merged Dataset.csv"

# %%
# Read movie data Files and store into Pandas DataFrames
m_netflix = pd.read_csv(movie_netflix)
s_netflix = pd.read_csv(stock_netflix)

s_netflix
# Out:
#     Unnamed: 0                      Area      Years     Revenue  Subscribers  \
# 0            0  United States and Canada  Q1 - 2018  1976157000     60909000
# 1            1  United States and Canada  Q2 - 2018  2049546000     61870000
# 2            2  United States and Canada  Q3 - 2018  2094850000     63010000
# 3            3  United States and Canada  Q4 - 2018  2160979000     64757000
# 4            4  United States and Canada  Q1 - 2019  2256851000     66633000
# ..         ...                       ...        ...         ...          ...
# 75          75              Asia-Pacific  Q4 - 2021   870705000     32632000
# 76          76              Asia-Pacific  Q1 - 2022   916754000     33719000
# 77          77              Asia-Pacific  Q2 - 2022   907719000     34799000
# 78          78              Asia-Pacific  Q3 - 2022   889037000     36228000
# 79          79              Asia-Pacific  Q4 - 2022   856711000     38023000
#
#           Open        High         Low       Close   Adj Close     Volume
# 0   291.940002  338.820007  271.220001  312.459991  312.459991  262006000
# 1   385.450012  419.769989  328.000000  337.450012  337.450012  305393800
# 2   375.850006  386.799988  271.209991  301.779999  301.779999  363589800
# 3   259.279999  358.850006  256.579987  339.500000  339.500000  306616400
# 4   359.000000  384.799988  342.269989  370.540009  370.540009  165079400
# ..         ...         ...         ...         ...         ...        ...
# 75  605.609985  609.989990  351.459991  427.140015  427.140015  241662000
# 76  376.799988  396.019989  185.600006  190.360001  190.360001  403325400
# 77  176.490005  230.750000  169.699997  224.899994  224.899994  270083700
# 78  237.850006  305.630005  211.729996  291.880005  291.880005  335263800
# 79  298.059998  369.019989  288.700012  353.859985  353.859985  206417400
#
# [80 rows x 11 columns]

# %%
s_netflix2 = s_netflix.set_index("Years")

NA_netflix = s_netflix2[(s_netflix2["Area"] == "United States and Canada")]

Asia_netflix = s_netflix2[(s_netflix2["Area"] == "Asia-Pacific")]

EurAF_netflix = s_netflix2[(s_netflix2["Area"] == "Europe,  Middle East and Africa")]

Latin_netflix = s_netflix2[(s_netflix2["Area"] == "Latin America")]

Latin_netflix
# Out:
#            Unnamed: 0           Area     Revenue  Subscribers        Open  \
# Years
# Q1 - 2018          40  Latin America   540182000     21260000  291.940002
# Q2 - 2018          41  Latin America   568071000     22795000  385.450012
# Q3 - 2018          42  Latin America   562307000     24115000  375.850006
# Q4 - 2018          43  Latin America   567137000     26077000  259.279999
# Q1 - 2019          44  Latin America   630472000     27547000  359.000000
# Q2 - 2019          45  Latin America   677136000     27890000  373.500000
# Q3 - 2019          46  Latin America   741434000     29380000  267.350006
# Q4 - 2019          47  Latin America   746392000     31417000  326.100006
# Q1 - 2020          48  Latin America   793453000     34318000  376.049988
# Q2 - 2020          49  Latin America   785368000     36068000  454.000000
# Q3 - 2020          50  Latin America   789384000     36324000  506.029999
# Q4 - 2020          51  Latin America   788522000     37537000  539.000000
# Q1 - 2021          52  Latin America   836647000     37894000  529.929993
# Q2 - 2021          53  Latin America   860882000     38658000  525.719971
# Q3 - 2021          54  Latin America   915297000     38988000  604.239990
# Q4 - 2021          55  Latin America   964150000     39961000  605.609985
# Q1 - 2022          56  Latin America   998948000     39610000  376.799988
# Q2 - 2022          57  Latin America  1030234000     39624000  176.490005
# Q3 - 2022          58  Latin America  1023945000     39936000  237.850006
# Q4 - 2022          59  Latin America  1016846000     41699000  298.059998
#
#                  High         Low       Close   Adj Close     Volume
# Years
# Q1 - 2018  338.820007  271.220001  312.459991  312.459991  262006000
# Q2 - 2018  419.769989  328.000000  337.450012  337.450012  305393800
# Q3 - 2018  386.799988  271.209991  301.779999  301.779999  363589800
# Q4 - 2018  358.850006  256.579987  339.500000  339.500000  306616400
# Q1 - 2019  384.799988  342.269989  370.540009  370.540009  165079400
# Q2 - 2019  384.760010  305.809998  322.989990  322.989990  196652500
# Q3 - 2019  308.750000  257.010010  287.410004  287.410004  231556400
# Q4 - 2019  359.850006  321.200012  345.089996  345.089996  169874000
# Q1 - 2020  449.519989  357.510010  419.850006  419.850006  225111600
# Q2 - 2020  575.369995  454.000000  488.880005  488.880005  232206300
# Q3 - 2020  572.489990  472.209991  475.739990  475.739990  154302400
# Q4 - 2020  593.289978  485.670013  532.390015  532.390015  139988600
# Q1 - 2021  563.559998  499.000000  513.469971  513.469971  111573300
# Q2 - 2021  557.539978  504.660004  517.570007  517.570007   77221200
# Q3 - 2021  690.969971  594.679993  690.309998  690.309998   98576300
# Q4 - 2021  609.989990  351.459991  427.140015  427.140015  241662000
# Q1 - 2022  396.019989  185.600006  190.360001  190.360001  403325400
# Q2 - 2022  230.750000  169.699997  224.899994  224.899994  270083700
# Q3 - 2022  305.630005  211.729996  291.880005  291.880005  335263800
# Q4 - 2022  369.019989  288.700012  353.859985  353.859985  206417400

# %%
 
plt.plot( Latin_netflix['Revenue'], color='blue')
plt.plot( NA_netflix['Revenue'], color='red')
plt.plot( EurAF_netflix['Revenue'], color='green')
plt.plot( Asia_netflix['Revenue'], color='orange')

plt.xticks( rotation='60')

plt.legend(["Latin America", "North America" , "Europe", 'Asia'])

plt.tight_layout()

plt.title('Netflix Revenue by Region, 2018-2022', fontsize=12)
plt.xlabel('Quarters', fontsize=12)
plt.ylabel('Revenue', fontsize=12)

plt.show()

# %%
labels = NA_netflix.index

data1 = NA_netflix["Close"]

width = 0.8


plt.xlabel("Quarters")
plt.ylabel("Closing Price of Netflix Stock ($)")
plt.title("Closing Price of Netflix Stock, 2018-2022")

plt.xticks(range(len(data1)), labels, rotation = "50")

plt.bar(np.arange(len(data1)), data1, width=width) 


plt.tight_layout()



plt.show()

# %%
plt.plot( Latin_netflix['Subscribers'], color='blue')
plt.plot( NA_netflix['Subscribers'], color='red')
plt.plot( EurAF_netflix['Subscribers'], color='green')
plt.plot( Asia_netflix['Subscribers'], color='orange')

plt.xticks( rotation='60')

plt.legend(["Latin America", "North America" , "Europe", 'Asia'])

plt.tight_layout()

plt.title('Number of Netflix Subscribers by Region, 2018-2022', fontsize=12)
plt.xlabel('Quarters', fontsize=12)
plt.ylabel('Number of Subscribers (10,000,000)', fontsize=12)

plt.show()

# %%
plt.plot( Latin_netflix['Volume'], color='blue')


plt.xticks(range(len(data1)), labels, rotation = "50")

plt.bar(np.arange(len(data1)), data1, width=width) 



plt.tight_layout()

plt.title('Trade Volume of Netflix Stock, 2018-2022', fontsize=12)
plt.xlabel('Quarters', fontsize=12)
plt.ylabel('Volume of Stock Traded', fontsize=12)

plt.show()

# %%
m_netflix
# Out:
#      Show_ID                       Movie Title                       Director  \
# 0         s1              Dick Johnson Is Dead                Kirsten Johnson
# 1         s7  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 2        s10                      The Starling                 Theodore Melfi
# 3        s14  Confessions of an Invisible Girl                  Bruno Garotti
# 4        s19                         Intrusion                     Adam Salky
# ...      ...                               ...                            ...
# 2290   s8242                           The CEO                 Kunle Afolayan
# 2291   s8310                     The Foreigner                Martin Campbell
# 2292   s8315                 The Frozen Ground                   Scott Walker
# 2293   s8321   The Girl with the Dragon Tattoo                  David Fincher
# 2294   s8707                    We the Animals                 Jeremiah Zagar
#
#                                           Country  Release_Year Rating_class  \
# 0                                   United States          2020        PG-13
# 1                                             NaN          2021           PG
# 2                                   United States          2021        PG-13
# 3                                             NaN          2021        TV-PG
# 4                                             NaN          2021        TV-14
# ...                                           ...           ...          ...
# 2290                                      Nigeria          2016        TV-14
# 2291  United Kingdom, China, United States, India          2017            R
# 2292                                United States          2013            R
# 2293                United States, Sweden, Norway          2011            R
# 2294                                United States          2018            R
#
#       Duration                                Categories   Type  IMDB_Score  \
# 0           90                             Documentaries  Movie         7.4
# 1           91                  Children & Family Movies  Movie         6.8
# 2          104                          Comedies, Dramas  Movie         6.3
# 3           91        Children & Family Movies, Comedies  Movie         5.2
# 4           94                                 Thrillers  Movie         5.3
# ...        ...                                       ...    ...         ...
# 2290       109   Dramas, International Movies, Thrillers  Movie         5.7
# 2291       113  Action & Adventure, International Movies  Movie         7.0
# 2292       106                         Dramas, Thrillers  Movie         6.4
# 2293       158                         Dramas, Thrillers  Movie         7.8
# 2294        93                Dramas, Independent Movies  Movie         6.9
#
#       IMDB_Votes
# 0         6390.0
# 1         3468.0
# 2        11733.0
# 3          966.0
# 4        15464.0
# ...          ...
# 2290       121.0
# 2291    112487.0
# 2292     62183.0
# 2293    454917.0
# 2294      4181.0
#
# [2295 rows x 11 columns]

# %%
plt.figure()
ax = m_netflix.plot.scatter(x='Duration', y='IMDB_Score')
plt.show()

# %%
# Distribution of Television vs Movie viewing by age category
# Indicates prevalence of mature themed television viewing for longer duration
# not many shows geared to children and youth audience

PG_netflix = m_netflix[(m_netflix["Rating_class"] == "PG")]
PG13_netflix = m_netflix[(m_netflix["Rating_class"] == "PG-13")]
R_netflix = m_netflix[(m_netflix["Rating_class"] == "R")]
TVPG_netflix = m_netflix[(m_netflix["Rating_class"] == "TV-PG")]
TVMA_netflix = m_netflix[(m_netflix["Rating_class"] == "TV-MA")]
TVY7_netflix = m_netflix[(m_netflix["Rating_class"] == "TV-Y7")]
TVY_netflix = m_netflix[(m_netflix["Rating_class"] == "TV-Y")]
TVG_netflix = m_netflix[(m_netflix["Rating_class"] == "TV-G")]
TV14_netflix = m_netflix[(m_netflix["Rating_class"] == "TV-14")]



ax = TVY7_netflix.plot.scatter(x='Duration', y='IMDB_Score', color = 'b', label ='TV-Y7')
TVG_netflix.plot.scatter(x='Duration', y='IMDB_Score', color = 'r',ax=ax, label ='TV-G')
TVY_netflix.plot.scatter(x='Duration', y='IMDB_Score', color = 'g',ax=ax, label ='TV-Y')


ax = PG_netflix.plot.scatter(x='Duration', y='IMDB_Score', color = 'b' ,label = 'PG movies')
plt.figure()
TVPG_netflix.plot.scatter(x='Duration', y='IMDB_Score', color = 'r',ax=ax, label ='TV-PG')


ax = PG13_netflix.plot.scatter(x='Duration', y='IMDB_Score', color = 'b', label ='PG-13 movies')
TV14_netflix.plot.scatter(x='Duration', y='IMDB_Score', color = 'r',ax=ax, label ='TV-14')


ax = R_netflix.plot.scatter(x='Duration', y='IMDB_Score', color = 'b', label ='R-rated movies')
TVMA_netflix.plot.scatter(x='Duration', y='IMDB_Score', color = 'r',ax=ax, label ='TV-MA')

plt.show()
